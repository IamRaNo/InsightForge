# %% [markdown]
# # Closing The Case - ***What Distinguishes Solved Cases from Unsolved Ones?***

# %% [markdown]
# ## ***Analysis*** of Data

# %% [markdown]
# ### ***Univariate*** Analysis

# %% [markdown]
# ### ***Bivariate*** Analysis

# %% [markdown]
# ### ***Multivariate*** Analysis Using ***Corelation*** Analysis

# %% [markdown]
# ## ***Statistical Test*** Based on Analysis

# %% [markdown]
# ### ***Numerical*** Inputs

# %% [markdown]
# ### ***Categorical*** Inputs

# %% [markdown]
# ## ***Summarry***
